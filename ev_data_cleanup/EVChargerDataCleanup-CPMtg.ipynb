# %% [markdown]
# # EV Charger Data Cleanup for the Energy Office
#
# June Chee, Transportation Energy Analyst with the Hawaii State Energy Office requested some assistance cleaning up their EV Charging Data. The data consists of three files, all available in this folder
#
# 1. **Hawaii EV App_Charging Stations List**: This is the charging station app that the Hawaii State Energy Office manages. Ideally the new data set would help to clean up and repopulate the information for this app. You can see how the app looks here: http://energy.hawaii.gov/testbeds-initiatives/ev-ready-program/ev-stations-hawaii-mobile-app
#
# - **AFDC Hawaii Charging Stations List**: This is the list you on the federal Alternative Fuels Data Center. You can access the station locater here: https://www.afdc.energy.gov/fuels/electricity_locations.html#/analyze?region=HI
#
# - **ChargePoint_Hawaii EV Charging Stations**: this is a data set from one of the major EV charging station vendors in Hawaii who have recently made updates and new installments to charging stations.

# %%
import pandas as pd
import numpy as np

# %%
Chargepoint = pd.read_csv("Chargepoint.csv")
EVApp =pd.read_csv("EVApp.csv")

# %% [markdown]
# ## EV App Dataset
#
# This is the target dataset. It has **257 Locations** and some specific geography including address, lattitude and longitude. The stations have ids but presumably that's within this system and does not have any other matching features in other datasets. Filtering out duplicates may be a matter of matching latitude and logitude... perhaps within a few feet? Or Address matches?

# %%
EVApp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 23 columns):
# Unnamed: 0              257 non-null int64
# Station ID              257 non-null int64
# Station name            257 non-null object
# Location                257 non-null object
# Island                  257 non-null object
# Address                 257 non-null object
# City                    257 non-null object
# State                   257 non-null object
# Zip Code                257 non-null int64
# Latitude                257 non-null object
# Longitude               257 non-null object
# Contact Name            118 non-null object
# Charge Fee              255 non-null object
# Park Fee                190 non-null object
# Parking Lot             99 non-null object
# Hours                   255 non-null object
# Ports                   257 non-null int64
# Restrictions            165 non-null object
# Number of Stations      257 non-null int64
# Charge Fees             256 non-null object
# Manufacturers           257 non-null object
# Charging Levels         257 non-null int64
# Date Initially Added    257 non-null object
# dtypes: int64(6), object(17)
# memory usage: 46.3+ KB

# %% [markdown]
# ## Chargepoint Data
# This is the dataset solely for chargepoint, probably the biggest individual provider? It has Addresses, but not latitudes and Longitudes. It might be possible to run these through a converter, or just to use the addresses.

# %%
Chargepoint.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 12 columns):
# Unnamed: 0                 148 non-null int64
# Station Name               148 non-null object
# Org Name                   148 non-null object
# Address 1                  148 non-null object
# City                       148 non-null object
# State                      148 non-null object
# Postal Code                148 non-null int64
# County                     140 non-null object
# Country                    148 non-null object
# No. of Ports               148 non-null int64
# Station Activation Type    148 non-null object
# Customer Category          148 non-null object
# dtypes: int64(3), object(9)
# memory usage: 14.0+ KB

# %% [markdown]
# ## Step 1: In EVApp, filter out all chargers that are not Chargepoint

# %%
EVApp_CPOnly = EVApp.loc[EVApp['Manufacturers']=='ChargePoint']

# %% [markdown]
# ## Step 1: Prefix column names to identify data set source
# this is needed because we will eventually create a dataset that includes both evapp and chargepoint datasets.
# we will want to identify columns that came from EVApp versus columns that came from Chargepoint

# %%
#prefix all column names with source
EVApp.rename(columns = lambda x: 'EV_'+x, inplace=True)
Chargepoint.rename(columns = lambda x: 'CH_'+x, inplace=True)

# %% [markdown]
# ## Step 2: Prepare addresses to use as an identifier between the datasets.
# Try using address.  We will need to make address conform to same format.
#
# Format:
# 1.  All upper case letters
# 2.  No okina
# 3.  Spell out all abbreviations.
# 4.  Remove periods
#
#
# In each data set, create a new column called 'Common Address'.

# %% [markdown]
# Right off the bat you can see that some addresses live in all three, but also that some contain duplicate listings in a single datasource.
#
# For example:
# 100 Ho'okele St	EVApp
# 100 Ho'okele St	Chargepoint
# 100 Ho'okele St	Chargepoint

# %%
df_streetabrevs = pd.read_csv(r'Street Abbreviations.csv') #https://mbiz.bf.umich.edu/mailsvcs/streetsuffixes.htm
df_streetabrevs = df_streetabrevs.append(pd.DataFrame([['North','N'],['South','S'],['EAST','E'],['WEST','W']], columns=['Full','Abbreviation']), ignore_index = True)

def _makeCommonAddress(Address):
#     take in an address string, return a common address string
    CommonAddress = Address #copy address string
    #do some initial transformations:
    CommonAddress = CommonAddress.upper()    
    CommonAddress = CommonAddress.replace('','') #remove okina
    CommonAddress = CommonAddress.replace('.','')
    CommonAddress = CommonAddress.replace(',','')
    CommonAddress = CommonAddress.replace('-','')  
    CommonAddress = CommonAddress.replace('/','')
    CommonAddress = CommonAddress.replace('\\','')
    CommonAddress = CommonAddress.replace("'",'') #remove okina    
    CommonAddress = CommonAddress.replace("’",'') #remove okina
    #before doing abbreviations transform, change all street conversions to upper case
#     CommonAddress = CommonAddress.upper()  
     #replace street abbreviations w/ full:
    ls_parts = CommonAddress.split(' ')
    def replace_part(part):
        val = df_streetabrevs.loc[df_streetabrevs['Abbreviation']==part,'Full']
        if len(val) > 0: return val.iloc[0]
        else: return part
    ls_parts_rev = [replace_part(part) for part in ls_parts]
    CommonAddress = ''.join(ls_parts_rev)
    #change all street conversions to upper case
    CommonAddress = CommonAddress.upper()    
    return CommonAddress

# %%
#here we make new dataframes using old ones that includes a common address column
EVApp['Cmn_Address'] = EVApp.apply(lambda row: _makeCommonAddress(row['EV_Address']), axis=1)
Chargepoint['Cmn_Address'] = Chargepoint.apply(lambda row: _makeCommonAddress(row['CH_Address 1']), axis=1)

# %% [markdown]
# ## Step 3: remove duplicate addresses
# In EVApp & Chargepoint (separately), select only unique rows using Cmn_Address column as unique key identifier
# **FUTURE WORK NOTE: we need to consider implications of ignoring data that we lose when removing duplicate address rows based on address.

# %%
EVApp = EVApp.groupby(['Cmn_Address'], as_index=False).first() #https://stackoverflow.com/questions/12322779/pandas-unique-dataframe
Chargepoint = Chargepoint.groupby(['Cmn_Address'], as_index=False).first()

EVApp.to_csv('EVApp_unique_addresses.csv', encoding='utf-8')
Chargepoint.to_csv('Chargepoint_unique_addresses.csv', encoding='utf-8')

# %% [markdown]
# ## Step 4: Revise EVApp to only include chargepoint manufacturers

# %%
EVApp = EVApp.loc[EVApp['EV_Manufacturers'] == 'ChargePoint']
EVApp.to_csv('EVApp_CP_unique_addresses.csv', encoding='utf-8')

# %% [markdown]
# ## Step 4: Merge EVApp & Chargepoint into a master data set

# %%
MasterData = pd.merge(EVApp, Chargepoint, on = 'Cmn_Address', how = 'outer')

# %% [markdown]
# ## Step 5: Make Only_In_EV.csv
# use MasterData data set to create a file that contains records existing in EVApp but not chargepoint

# %%
Only_In_EV = MasterData.loc[MasterData['EV_Address'].notna() & MasterData['CH_Address 1'].isna()]
Only_In_EV.to_csv('Only_In_EV.csv', encoding='utf-8')
display(Only_In_EV)
# Out:
#                              Cmn_Address  EV_Unnamed: 0  EV_Station ID  \
# 0   1001KAMOKILABOULEVARDKAPOLEIBUILDING          257.0          905.0
# 4                             1170NUUANU           94.0          489.0
# 5                     1380LUSITANASTREET           75.0          447.0
# 9                        2345KUHIOAVENUE          242.0          869.0
# 10                     3221WAIALAEAVENUE           52.0          395.0
# 14                        410KOLOASTREET          143.0          641.0
# 16              4450KAPOLEIPARKWAYSTE100          159.0          673.0
# 18                           724ILANIWAI          223.0          819.0
#
#                       EV_Station name  \
# 0                     Campbell Square
# 4   Smith-Beretania Parking Structure
# 5   Queen’s Physician Office Building
# 9          International Market Place
# 10            Kaimuki Shopping Center
# 14                        BMW of Maui
# 16                     Target-Kapolei
# 18                Green Energy Outlet
#
#                                           EV_Location EV_Island  \
# 0                            P1 across from elevators      Oahu
# 4   Entrance on Beretania Street between Nuuanu Av...      Oahu
# 5   1 Charger at POB 1 lot on Lusitaina St. Main e...      Oahu
# 9                                                   .      Oahu
# 10        The charging station is in the parking lot.      Oahu
# 14  The charger is located in the outside parking lot      Maui
# 16             Charger located in front of exit doors      Oahu
# 18  Green spot for EV Charging in front of lot. Ot...      Oahu
#
#                               EV_Address   EV_City EV_State  EV_Zip Code  \
# 0   1001 Kamokila Blvd, Kapolei Building   Kapolei       HI      96707.0
# 4                            1170 Nuuanu  Honolulu       HI      96817.0
# 5                   1380 Lusitana street  Honolulu       HI      96813.0
# 9                         2345 Kuhio Ave  Honolulu       HI      96815.0
# 10                      3221 Waialae Ave  Honolulu       HI      96816.0
# 14                      410 Koloa Street   Kahului       HI      96732.0
# 16             4450 Kapolei Pkwy Ste 100   Kapolei       HI      96707.0
# 18                          724 Ilaniwai  Honolulu       HI      96813.0
#
#             ...          CH_Org Name CH_Address 1 CH_City CH_State  \
# 0           ...                  NaN          NaN     NaN      NaN
# 4           ...                  NaN          NaN     NaN      NaN
# 5           ...                  NaN          NaN     NaN      NaN
# 9           ...                  NaN          NaN     NaN      NaN
# 10          ...                  NaN          NaN     NaN      NaN
# 14          ...                  NaN          NaN     NaN      NaN
# 16          ...                  NaN          NaN     NaN      NaN
# 18          ...                  NaN          NaN     NaN      NaN
#
#    CH_Postal Code CH_County CH_Country  CH_No. of Ports  \
# 0             NaN       NaN        NaN              NaN
# 4             NaN       NaN        NaN              NaN
# 5             NaN       NaN        NaN              NaN
# 9             NaN       NaN        NaN              NaN
# 10            NaN       NaN        NaN              NaN
# 14            NaN       NaN        NaN              NaN
# 16            NaN       NaN        NaN              NaN
# 18            NaN       NaN        NaN              NaN
#
#    CH_Station Activation Type  CH_Customer Category
# 0                         NaN                   NaN
# 4                         NaN                   NaN
# 5                         NaN                   NaN
# 9                         NaN                   NaN
# 10                        NaN                   NaN
# 14                        NaN                   NaN
# 16                        NaN                   NaN
# 18                        NaN                   NaN
#
# [8 rows x 36 columns]

# %% [markdown]
# ## Step 6: Make Only_In_CH.csv
# use MasterData data set to create a file that contains records existing in chargepoint but not EVApp

# %%
Only_In_CH = MasterData.loc[MasterData['CH_Address 1'].notna() & MasterData['EV_Address'].isna()]
Only_In_CH.to_csv('Only_In_CH.csv', encoding='utf-8')
display(Only_In_CH.head(10))
# Out:
#                  Cmn_Address  EV_Unnamed: 0  EV_Station ID EV_Station name  \
# 29         1000ULUOHIASTREET            NaN            NaN             NaN
# 30     1001KAMOKILABOULEVARD            NaN            NaN             NaN
# 31          101MALUNIUAVENUE            NaN            NaN             NaN
# 32         111911234THAVENUE            NaN            NaN             NaN
# 33  11511185WAIANUENUEAVENUE            NaN            NaN             NaN
# 34          1170NUUANUAVENUE            NaN            NaN             NaN
# 35         1189WAIMANUSTREET            NaN            NaN             NaN
# 36  1234SOUTHBERETANIASTREET            NaN            NaN             NaN
# 37           1260KUALASTREET            NaN            NaN             NaN
# 38     1288ALAMOANABOULEVARD            NaN            NaN             NaN
#
#    EV_Location EV_Island EV_Address EV_City EV_State  EV_Zip Code  \
# 29         NaN       NaN        NaN     NaN      NaN          NaN
# 30         NaN       NaN        NaN     NaN      NaN          NaN
# 31         NaN       NaN        NaN     NaN      NaN          NaN
# 32         NaN       NaN        NaN     NaN      NaN          NaN
# 33         NaN       NaN        NaN     NaN      NaN          NaN
# 34         NaN       NaN        NaN     NaN      NaN          NaN
# 35         NaN       NaN        NaN     NaN      NaN          NaN
# 36         NaN       NaN        NaN     NaN      NaN          NaN
# 37         NaN       NaN        NaN     NaN      NaN          NaN
# 38         NaN       NaN        NaN     NaN      NaN          NaN
#
#              ...                                                  CH_Org Name  \
# 29           ...                                    City & County of Honolulu
# 30           ...            James Campbell Company LLC co MMI Realty Servi...
# 31           ...                                         Highmark Capital LLC
# 32           ...                                              CBI Inc. Hawaii
# 33           ...                    Hawaii Health Systems Hilo Medical Center
# 34           ...                                    City & County of Honolulu
# 35           ...                                           Waihonua at Kewalo
# 36           ...                                    MMI Realty Services, Inc.
# 37           ...                                  Hickam Federal Credit Union
# 38           ...                                               Hokua Honolulu
#
#                 CH_Address 1     CH_City CH_State CH_Postal Code  \
# 29         1000 Ulu'Ohi'a St     Kapolei   Hawaii        96707.0
# 30        1001 Kamokila Blvd     Kapolei   Hawaii        96707.0
# 31           101 Maluniu Ave      Kailua   Hawaii        96734.0
# 32         1119-1123 4th Ave    Honolulu   Hawaii        96816.0
# 33  1151-1185 Waianuenue Ave        Hilo   Hawaii        96720.0
# 34           1170 Nuuanu Ave    Honolulu   Hawaii        96817.0
# 35           1189 Waimanu St    Honolulu   Hawaii        96814.0
# 36      1234 S. Beretania St    Honolulu   Hawaii        96814.0
# 37             1260 Kuala St  Pearl City   Hawaii        96782.0
# 38       1288 Ala Moana Blvd    Honolulu   Hawaii        96814.0
#
#           CH_County     CH_Country  CH_No. of Ports  \
# 29  Honolulu County  United States              1.0
# 30  Honolulu County  United States              2.0
# 31  Honolulu County  United States              2.0
# 32  Honolulu County  United States              2.0
# 33    Hawaii County  United States              2.0
# 34  Honolulu County  United States              1.0
# 35  Honolulu County  United States              1.0
# 36  Honolulu County  United States              2.0
# 37  Honolulu County  United States              1.0
# 38  Honolulu County  United States              2.0
#
#    CH_Station Activation Type    CH_Customer Category
# 29                     Public               Municipal
# 30                     Public               Workplace
# 31                     Public  Multifamily Commercial
# 32                     Public                  Retail
# 33                     Public              Healthcare
# 34                     Public               Municipal
# 35                     Public               Workplace
# 36                     Public               Workplace
# 37                     Public               Workplace
# 38                     Public  Multifamily Commercial
#
# [10 rows x 36 columns]

# %% [markdown]
# ## Step 7: Make In_EV_CH.csv
# use MasterData data set to create a file that contains records existing in chargepoint but not EVApp

# %%
In_EV_CH = MasterData.loc[MasterData['EV_Address'].notna() & MasterData['CH_Address 1'].notna()]
In_EV_CH.to_csv('In_EV_CH.csv', encoding='utf-8')
display(In_EV_CH)
# Out:
#                 Cmn_Address  EV_Unnamed: 0  EV_Station ID  \
# 1          100HOOKELESTREET          198.0          765.0
# 2          100NOHEAKAIDRIVE           23.0          315.0
# 3          1031NUUANUAVENUE           95.0          491.0
# 6         151KAPAHULUAVENUE           92.0          485.0
# 7   155NORTHBERETANIASTREET           96.0          493.0
# 8          200NOHEAKAIDRIVE           19.0          307.0
# 11          345HAHANISTREET          184.0          735.0
# 12         391MAKAALASTREET          183.0          733.0
# 13          3970KAANASTREET          195.0          759.0
# 15       4380LAWEHANASTREET          158.0          671.0
# 17       650SOUTHKINGSTREET           91.0          483.0
# 19    745455MAKALABOULEVARD          160.0          675.0
# 20       745533LOLOKUSTREET          144.0          643.0
# 21            777WARDAVENUE           93.0          487.0
# 22           801SOUTHSTREET          203.0          777.0
# 23    825KAPIOLANIBOULEVARD          194.0          755.0
# 24       888SOUTHKINGSTREET          156.0          667.0
# 25       921185ALIINUIDRIVE           30.0          343.0
# 26        92149WAIPAHEPLACE          100.0          525.0
# 27       981079MOANALUAROAD          154.0          663.0
# 28          WAHINEPIOAVENUE          137.0          627.0
#
#                                      EV_Station name  \
# 1                         Target Corp Maui - Kahului
# 2                           Marriott Maui Ocean Club
# 3          Chinatown Gateway Plaza Parking Structure
# 6          Honolulu Zoo Parking Lot (Currently DOWN)
# 7                      Hale Pauahi Parking Structure
# 8                                 Hyatt Regency Maui
# 11                                    Target- Kailua
# 12                                      Target- Hilo
# 13                                 5th Circuit Court
# 15                                  Target- Honolulu
# 17               Fasi Civic Center Parking Structure
# 19                               Target- Hawaii-Kona
# 20                                       BMW of Kona
# 21           Neal Blaisdell Center Parking Structure
# 22                                       801 PHASE 1
# 23                                     BMW of Hawaii
# 24  Straub Clinic & Hospital - Hawaii Pacific Health
# 25          Aulani A Disney Resort and Spa, Ko Olina
# 26                    Marriott's Ko Olina Beach Club
# 27  Pali Momi Medical Center - Hawaii Pacific Health
# 28                University of Hawai‘i Maui College
#
#                                           EV_Location EV_Island  \
# 1                                         Parking lot      Maui
# 2   The charging station is located in the Valet s...      Maui
# 3   The entrance to the parking structure is locat...      Oahu
# 6   Entrance to parking lot is on Kapahulu.  Follo...      Oahu
# 7   The entrance is on Beretania Street.  Follow b...      Oahu
# 8   In the Lahaina parking area, take a left turn ...      Maui
# 11                                             Target      Oahu
# 12                   In front of store, near ADA spot    Hawaii
# 13            Southwest corner of the building; Gated     Kauai
# 15  Middle row of parking lot - ground floor near ...      Oahu
# 17  Public parking entrance is on Alapai Street an...      Oahu
# 19  Charging Station is near the exit doors in the...    Hawaii
# 20              Charger is in the outside parking lot    Hawaii
# 21  Enter S. King Street/Victoria street.  Follow ...      Oahu
# 22          The station is located in Visitor Parking      Oahu
# 23                                  At the dealership      Oahu
# 24  2nd floor parking garage- first 2 stalls on th...      Oahu
# 25                           See Valet for Assistance      Oahu
# 26  1 charging station each in Hale Moana Parking ...      Oahu
# 27  Charging stations located P1 level visitor par...      Oahu
# 28     Parking lot at Kaaike building under PV Array.      Maui
#
#                EV_Address      EV_City EV_State  EV_Zip Code  \
# 1         100 Ho'okele St      Kahului       HI      96732.0
# 2     100 Nohea Kai Drive      Lahaina       HI      96761.0
# 3         1031 Nuuanu Ave     Honolulu       HI      96817.0
# 6     151 Kapahulu Avenue     Honolulu       HI      96815.0
# 7     155 N Beretania St.     Honolulu       HI      96817.0
# 8     200 Nohea Kai Drive      Lahaina       HI      96761.0
# 11          345 Hahani St       Kailua       HI      96734.0
# 12     391 Makaala Street         Hilo       HI      96720.0
# 13          3970 Kaana St        Lihue       HI      96766.0
# 15       4380 Lawehana St     Honolulu       HI      96818.0
# 17     650 S. King Street     Honolulu       HI      96813.0
# 19    74-5455 Makala Blvd  Kailua Kona       HI      96740.0
# 20  74-5533 Loloku Street  Kailua Kona       HI      96740.0
# 21        777 Ward Avenue     Honolulu       HI      96814.0
# 22           801 South St     Honolulu       HI      96813.0
# 23     825 Kapiolani Blvd     Honolulu       HI      96813.0
# 24          888 S King St     Honolulu       HI      96813.0
# 25  92-1185 Aliinui Drive      Kapolei       HI      96707.0
# 26      92-149 Waipahe Pl      Kapolei       HI      96707.0
# 27    98-1079 Moanalua Rd         Aiea       HI      96701.0
# 28          Wahinepio Ave      Kahului       HI      96732.0
#
#              ...                             CH_Org Name  \
# 1            ...                      Target Corporation
# 2            ...                            Marriott MOC
# 3            ...               City & County of Honolulu
# 6            ...               City & County of Honolulu
# 7            ...               City & County of Honolulu
# 8            ...              Hyatt Regency Lahaina Maui
# 11           ...                      Target Corporation
# 12           ...                      Target Corporation
# 13           ...                       5th Circuit Court
# 15           ...                      Target Corporation
# 17           ...               City & County of Honolulu
# 19           ...                      Target Corporation
# 20           ...                           BMW of Hawaii
# 21           ...               City & County of Honolulu
# 22           ...                     801 South Street HI
# 23           ...                           BMW of Hawaii
# 24           ...               HPH Straub Medical Center
# 25           ...                           Disney-Aulani
# 26           ...                             Marriott Ko
# 27           ...            HPH Pali Momi Medical Center
# 28           ...                         UH Maui College
#
#              CH_Address 1      CH_City CH_State CH_Postal Code  \
# 1         100 Ho'okele St      Kahului   Hawaii        96732.0
# 2        100 Nohea Kai Dr      Lahaina   Hawaii        96761.0
# 3         1031 Nuuanu Ave     Honolulu   Hawaii        96817.0
# 6        151 Kapahulu Ave     Honolulu   Hawaii        96815.0
# 7      155 N Beretania St     Honolulu   Hawaii        96817.0
# 8        200 Nohea Kai Dr      Lahaina   Hawaii        96761.0
# 11          345 Hahani St       Kailua   Hawaii        96734.0
# 12         391 Makaala St         Hilo   Hawaii        96720.0
# 13          3970 Kaana St       L?hu?e   Hawaii        96766.0
# 15       4380 Lawehana St     Honolulu   Hawaii        96818.0
# 17          650 S King St     Honolulu   Hawaii        96813.0
# 19    74-5455 Makala Blvd  Kailua-Kona   Hawaii        96740.0
# 20      74-5533 Loloku St  Kailua-Kona   Hawaii        96740.0
# 21           777 Ward Ave     Honolulu   Hawaii        96814.0
# 22           801 south st     Honolulu   Hawaii        96813.0
# 23     825 Kapiolani Blvd     Honolulu   Hawaii        96813.0
# 24          888 S King St     Honolulu   Hawaii        96813.0
# 25  92-1185 Aliinui Drive      Kapolei   Hawaii        96707.0
# 26      92-149 Waipahe Pl      Kapolei   Hawaii        96707.0
# 27    98-1079 Moanalua Rd         Aiea   Hawaii        96701.0
# 28          Wahinepio Ave      Kahului   Hawaii        96732.0
#
#           CH_County     CH_Country  CH_No. of Ports  \
# 1       Maui County  United States              2.0
# 2       Maui County  United States              1.0
# 3   Honolulu County  United States              1.0
# 6   Honolulu County  United States              1.0
# 7   Honolulu County  United States              1.0
# 8       Maui County  United States              2.0
# 11  Honolulu County  United States              2.0
# 12    Hawaii County  United States              2.0
# 13     Kauai County  United States              1.0
# 15  Honolulu County  United States              2.0
# 17  Honolulu County  United States              1.0
# 19    Hawaii County  United States              2.0
# 20    Hawaii County  United States              1.0
# 21  Honolulu County  United States              1.0
# 22  Honolulu County  United States              1.0
# 23  Honolulu County  United States              2.0
# 24  Honolulu County  United States              2.0
# 25  Honolulu County  United States              1.0
# 26  Honolulu County  United States              2.0
# 27  Honolulu County  United States              2.0
# 28      Maui County  United States              2.0
#
#    CH_Station Activation Type    CH_Customer Category
# 1                      Public                  Retail
# 2                      Public             Hospitality
# 3                      Public                  Retail
# 6                      Public             Hospitality
# 7                      Public  Multifamily Commercial
# 8                      Public             Hospitality
# 11                     Public                  Retail
# 12                     Public                  Retail
# 13                     Public               Workplace
# 15                     Public                  Retail
# 17                     Public               Municipal
# 19                     Public                  Retail
# 20                     Public                  Retail
# 21                     Public               Workplace
# 22                     Public               Workplace
# 23                     Public                  Retail
# 24                     Public              Healthcare
# 25                     Public             Hospitality
# 26                     Public             Hospitality
# 27                     Public              Healthcare
# 28                     Public               Education
#
# [21 rows x 36 columns]
