# %% [markdown]
# # Skills Backlog / Blueprint
#
# Creating (and periodically revisiting and refining) your __skills backlog__ is one of the most important parts of the skill building process. A well defined skill goal will ensure that you spend your time effectively on something tangible and useful.
#
# #### User Stories
# You will create a user story for each sprint to capture the skill you want to build and why. User stories have three parts
#
# 1. As a [---------------]
# 2. I need [---------------]
# 3. So that [---------------]
#
# #### Developing your Skills Backlog
#
# I recommend taking the following steps to come up with your skills Backlog
# 1. Go through the blueprint ([pdf](Blueprints.pdf) / [xlsx](Blueprints.xlsx)) and highlight the user story or user stories that seem interesting to you. You might follow a track if you think that would drive your use. Or just go with the ones you're drawn to
# 2. Take notes about why each seemed interesting to you, particularly if you can think of a specific application in your life or work or future interests.
# 3. Personalize the user story to include the skill you'd like to build and how you'd like to apply it using the notes and thoughts generated by the process above to guide your development.
# 4. If you have questions about what something is or what it means, google around a bit. Or ask about it on Slack!
#
# #### Add your Skill Backlog to the Class Trello Board
# Create a new __List__ in Trello using your name as the title in the [class Trello board](https://trello.com/b/7586eapN/devleague-big-data-analyst-bootcamp). Create a __card__ for each skill / user story in your skills backlog. Attach a trello green "skill" __label__ to each card and __assign__ it to yourself.
#
# #### Sample Skills Backlog Courtesy Tori Larson.
#
# **Note from Tori** - Hello Team! Below you will find my Skills backlog in the form of user stories. Please note that these are not final, week 40 is a long way away and you probably wont have the same questions as you do now. I wrote these because they are things I am excited to learn about now, but I am mostly excited to see what questions I will have in the future!
#
# __Sprint 1: Data Formats & Terminology__ - As an HR coordinator I need to convert birthday data into month and day data programmatically so I can create birthday cards more efficiently.
#
# __Sprint 2: Connecting to Data Sources__ - As an HR coordinator I need to use web scraping tools so that I can automatically generate reports and save time. (Scrapy)
#
# __Sprint 3: Data Operations__ - As a coding novice I need to learn basic coding so I know what it is and what can do with it.
#
# __Sprint 4: Data Manipulation Libraries and Tools__ - As a prospective big data analyzer, I would like to learn more about python and see how it relates it to the rest of my work.
#
# __Sprint 5: Summarizing & Describing__ - As a student that finds looking for errors tedious I want to work on identifying and fixing errors in order to become more observant in my work.
#
# __Sprint 6: Preliminary Findings and Hypotheses__ - As an HR coordinator I need an employee information dashboard so I may easily access employee information that is not readily available.
#
# __Sprint 7: Sampling, Instruments, and the Bias Introduced by both__ - As an HR coordinator I need to set up effective experiments and see which tactics get the most unbiased information from associates.
#
# __Sprint 8: Implementing Tests__ - As an HR coordinator I need to deploy surveys to my associates so I am able to gather information about their feelings on work like balance.
#
# __Sprint 9: Random/Stochastic Processes and Variables__ - As an HR coordinator I need understand variation so that I can see which data collected at work may be subject to it.
#
# __Sprint 10: Applying Probability Models__ - As a probability novice I need to understand the different types of probability models in order to apply them effectively in my work
#
# __Sprint 11: Population Estimates and Hypotheses__ - As a data novice I would like to learn which questions are the most important to ask and which to leave out in order to make a better hypothesis.
#
# __Sprint 12: Linear Regression Models__ - As an HR coordinator I need to build a regression model in order to understand different factors that affect employees.
#
# __Sprint 13: Machine Learning Capabilities__ - As someone who knows nothing about machine learning I would like to learn the basics in order to see how it can make working easier
#
# __Sprint 14: Machine Learning Optimization__ - As a prospective data freelancer I need to understand how to tweak information the organization gives me in order to create a better performing model.
#
# __Sprint 15: Sanitizing Data__ - As a prospective freelancer I want to know what tools I can use to depersonalize data in order to keep sensitive information secure.
#
# __Sprint 16: Securing Data__ - As a prospective freelancer I need to know how to keep customer data secure in order to keep confidentiality and trust.
#
# __Sprint 17: Storing and Computing in the Cloud__ - As an HR coordinator I need to know how to access cloud based storage so I am not constrained by my company’s software.
#
# __Sprint 18: Performance__ - As an HR coordinator I need to learn about my corporate data systems so that I may build tools to work with them and not take up company resources or breach company policy.
#
# __Sprint 19: Interactive Tools & Dashboards__ - As a data analyzer I would like to create a dashboard to easily and creatively show my data findings to others.
#
# __Sprint 20: Integrated Analytical Tools__ - As an HR coordinator I need to learn how to create interactive tools to deploy that could help my HR team with their day to day duties.
